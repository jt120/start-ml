# %%
import pandas as pd
import tushare as ts

# %%
cons = ts.get_apis()

# %%
df = ts.bar('600020', conn=cons, adj='qfq', freq='D', start_date='2017-01-01')
df.head()
# Out:
#               code  open close  high   low       vol      amount
# datetime
# 2017-11-03  600020  5.22  5.17  5.25  5.12  123781.0  64166988.0
# 2017-11-02  600020  5.26  5.23  5.28  5.21   96733.0  50706744.0
# 2017-11-01  600020  5.26  5.27  5.29  5.24  108995.0  57382388.0
# 2017-10-31  600020  5.26  5.27  5.29  5.23   96984.0  50993220.0
# 2017-10-30  600020  5.33  5.25  5.36  5.20  163544.0  85857792.0

# %%
import sqlite3
con = sqlite3.connect('d:/go/data/stock')
df.to_sql('d_600020', con=con)

# %%
all_stock = ts.get_stock_basics()
all_stock.head()
# Out:
#         name industry area      pe  outstanding  totals  totalAssets  \
# code
# 603659  N璞泰来     化工原料   上海   23.84         0.64    4.33    289609.25
# 603289  泰瑞机器     专用机械   浙江   36.38         0.51    2.04     88554.82
# 300708  聚灿光电      半导体   江苏   32.15         0.64    2.57    113054.97
# 300220  金运激光      元器件   湖北  133.64         1.25    1.26     40720.69
# 600807  天业股份     区域地产   山东   82.80         7.87    8.85   1011372.69
#
#         liquidAssets  fixedAssets   reserved    ...     bvps    pb  \
# code                                            ...
# 603659     238756.02     23142.92   12072.73    ...     3.58  6.65
# 603289      68437.21     15267.82    7229.90    ...     3.35  4.48
# 300708      53496.63     47045.95   17322.55    ...     2.85  5.42
# 300220      22521.49      8499.49    8362.66    ...     2.37  8.42
# 600807     772294.19     21063.74  116470.65    ...     2.34  5.03
#
#         timeToMarket      undp  perundp    rev  profit    gpr    npr   holders
# code
# ...

# %%
import pandas.io.sql as sql

# %%
df_2 = sql.read_sql('select * from d_603659', con)
df_2.head()
# Out:
#               datetime    code   open  close   high    low    vol    amount
# 0  2017-11-03 00:00:00  603659  23.80  23.80  23.80  23.80  217.0  517912.0

# %%
print(all_stock.index)
# Out:
# Index(['603659', '603289', '300708', '300220', '600807', '603912', '603929',
#        '002908', '002893', '002156',
#        ...
#        '000511', '000155', '603970', '603916', '603856', '603809', '603661',
#        '603619', '603605', '603507'],
#       dtype='object', name='code', length=3440)

# %%
for code in all_stock.index:
    try:      
        df = ts.bar(code, conn=cons, adj='qfq', freq='D')
        df.to_sql('d_'+code, con=con, if_exists='replace')
        print('save', code)
    except:
        print('fail', code)
# Out:
# save 603659
# save 603289
# save 300708
# save 300220
# save 600807
# save 603912
# save 603929
# save 002908
# save 002893
# save 002156
# save 603466
# save 002910
# save 603559
# save 300712
# save 603722
# save 300706
# save 300715
# save 002848
# save 603260
# save 300713
# save 603533
# save 300474
# save 603937
# save 603607
# save 300531
# save 300711
# save 002907
# save 002409
# save 002909
# save 300221
# save 000852
# save 002430
# save 000582
# save 603458
# save 300046
# save 002089
# save 603233
# save 000917
# save 002371
# save 002722
# save 300493
# save 000058
# save 300441
# save 300672
# save 002511
# save 300236
# save 300522
# save 002778
# save 002008
# save 600196
# save 601231
# save 000403
# save 000895
# save 000737
# save 300218
# save 600076
# save 603690
# save 300488
# save 300668
# save 002408
# save 002365
# save 300700
# save 300613
# save 600835
# save 002522
# save 300472
# save 000803
# save 300699
# save 300587
# save 603385
# save 002238
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2017-11-03'], dtype='datetime64[ns]', name='datetime', freq=None)
